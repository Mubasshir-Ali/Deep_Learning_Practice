# %% [markdown]
# <a href="https://colab.research.google.com/github/Mubasshir-Ali/Deep_Learning_Practice/blob/master/Color_Images_Dogs_vs_Cats_Without_Augmentation_Using_CNNS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#@title Dogs vs Cats Image Classification Without Image Augmentation

# %%
#@title Import Packages

# %%
#from __future__ absolute_import, division, print_function

# %%
import tensorflow as tf

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
import os
import numpy as np
import matplotlib.pyplot as plt

# %%
import logging
logger = tf.get_logger()
logger.setLevel(logging.ERROR)

# %%
#@title Data Loading

# %%
_URL = 'https://storage.googleapis.com/mledu-datasets/cats_and_dogs_filtered.zip'
zip_dir = tf.keras.utils.get_file('cats_and_dogs_filterted.zip', origin=_URL, extract=True)
# Out:
# Downloading data from https://storage.googleapis.com/mledu-datasets/cats_and_dogs_filtered.zip
# 68608000/68606236 [==============================] - 0s 0us/step

# %%
zip_dir_base = os.path.dirname(zip_dir)
# !find $zip_dir_base -type d -print
# Out:
# /root/.keras/datasets
# /root/.keras/datasets/cats_and_dogs_filtered
# /root/.keras/datasets/cats_and_dogs_filtered/validation
# /root/.keras/datasets/cats_and_dogs_filtered/validation/cats
# /root/.keras/datasets/cats_and_dogs_filtered/validation/dogs
# /root/.keras/datasets/cats_and_dogs_filtered/train
# /root/.keras/datasets/cats_and_dogs_filtered/train/cats
# /root/.keras/datasets/cats_and_dogs_filtered/train/dogs

# %%
# We'll now assign variables with the proper file path for the training and validation sets.
base_dir = os.path.join(os.path.dirname(zip_dir), 'cats_and_dogs_filtered')
train_dir = os.path.join(base_dir, 'train')
validation_dir = os.path.join(base_dir, 'validation')

train_cats_dir = os.path.join(train_dir, 'cats') # directory training cat pictures
train_dogs_dir = os.path.join(train_dir, 'dogs') # directory training dog pictures

validation_cats_dir = os.path.join(validation_dir, 'cats') # directory validation cat pictures
validation_dogs_dir = os.path.join(validation_dir, 'dogs') # directory validation dog pictures

# %%
#@title Understanding Our Data

# %%
# Let's look at how many cats and dogs images we have in our training and validation directory
num_cats_tr = len(os.listdir(train_cats_dir))
num_dogs_tr = len(os.listdir(train_dogs_dir))

num_cats_val = len(os.listdir(validation_cats_dir))
num_dogs_val = len(os.listdir(validation_dogs_dir))

total_train = num_cats_tr + num_dogs_tr
total_val = num_cats_val + num_dogs_val

# %%
print('Total Training Cat Images:', num_cats_tr)
print('Total Training Dog Images:', num_dogs_tr)

print('Total Validation Cat Images:', num_cats_val)
print('Total Validation Dog Images:', num_dogs_val)

print('---------------------------')

print('Total Training Images:', total_train)
print('Total Validation Images:', total_val)
# Out:
# Total Training Cat Images: 1000
# Total Training Dog Images: 1000
# Total Validation Cat Images: 500
# Total Validation Dog Images: 500
# ---------------------------
# Total Training Images: 2000
# Total Validation Images: 1000

# %%
#@title Setting Model Parameters

# %%
# Number of training examples to process before updating our models variables
BATCH_SIZE = 100

# Our training data consists of images with width of 150 pixels and height of 150 pixels
IMG_SHAPE = 150

# %%
#@title Data Preparation

# %% [markdown]
# Images must be formatted into appropriately pre-processed floating point tensors before being fed into the network. The steps involved in preparing these images are:
# 1.   Read images from the disk
#
# 1.   Decode contents of these images and convert it into proper grid format as per their RGB content
# 2.   Convert them into floating point tensors
#
#
# 4.   Rescale the tensors from values between 0 and 255 to values between 0 and 1, as neural networks prefer to deal with small input values.

# %%
# Generator our training data
train_image_generator = ImageDataGenerator(rescale = 1./255)

# Generator our validation data
validation_image_generator = ImageDataGenerator(rescale = 1./255)

# %%
train_data_gen = train_image_generator.flow_from_directory(batch_size = BATCH_SIZE, 
                                                           directory = train_dir, 
                                                           shuffle = True, 
                                                           target_size = (IMG_SHAPE, IMG_SHAPE), 
                                                           class_mode = 'binary')
# Out:
# Found 2000 images belonging to 2 classes.

# %%
val_data_gen = validation_image_generator.flow_from_directory(batch_size = BATCH_SIZE, 
                                                           directory = validation_dir, 
                                                           shuffle = True, 
                                                           target_size = (IMG_SHAPE, IMG_SHAPE), 
                                                           class_mode = 'binary')
# Out:
# Found 1000 images belonging to 2 classes.

# %%
#@title Visualizing Training Images

# %%
# We can visualize our training images by getting a batch of images from the training generator, and then plotting a few of them using matplotlib.
sample_training_images, _ = next(train_data_gen)

# %%
# The next function returns a batch from the dataset. One batch is a tuple of (many images, many labels). For right now, we're discarding the labels because we just want to look at the images.
def plotImages(images_arr):
  fig, axes = plt.subplots(1, 5, figsize = (20, 20))
  axes = axes.flatten()
  for img, ax in zip(images_arr, axes):
      ax.imshow(img)
  
  plt.tight_layout()
  plt.show()

# %%
# Plot images 0-4
plotImages(sample_training_images[:5])

# %%
#@title Model Creation

# %%
#@title Define The Model

# %% [markdown]
# The model consists of four convolution blocks with a max pool layer in each of them. Then we have a fully connected layer with 512 units, with a relu activation function. The model will output class probabilities for two classes — dogs and cats — using softmax.

# %%
model = tf.keras.models.Sequential([
    tf.keras.layers.Conv2D(32, (33), activation = 'relu', input_shape = (150, 150, 3)), 
    tf.keras.layers.MaxPooling2D(2, 2), 

    tf.keras.layers.Conv2D(64, (3, 3), activation = 'relu'), 
    tf.keras.layers.MaxPooling2D(2, 2), 

    tf.keras.layers.Conv2D(128, (3, 3), activation = 'relu'),
    tf.keras.layers.MaxPooling2D(2, 2), 

    tf.keras.layers.Conv2D(128, (3, 3), activation = 'relu'), 
    tf.keras.layers.MaxPooling2D(2, 2),

    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(512, activation = 'relu'), 
    tf.keras.layers.Dense(2)                                
])

# %%
#@title Compile The Model

# %%
model.compile(optimizer = 'adam', 
              loss = tf.keras.losses.SparseCategoricalCrossentropy(from_logits = True), 
              metrics = ['accuracy'] 
              )

# %%
#@title Model Summary

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 118, 118, 32)      104576
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 59, 59, 32)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 57, 57, 64)        18496
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 28, 28, 64)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 26, 26, 128)       73856
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 13, 13, 128)       0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 11, 11, 128)       147584
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 5, 5, 128)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 3200)              0
# _________________________________________________________________
# dense (Dense)                (None, 512)               1638912
# _________________________________________________________________
# dense_1 (Dense)              (None, 2)                 1026
# =================================================================
# Total params: 1,984,450
# Trainable params: 1,984,450
# Non-trainable params: 0
# _________________________________________________________________

# %%
#@title Train The Model

# %%
EPOCHS = 100
history = model.fit_generator(
    train_data_gen, 
    steps_per_epoch = int(np.ceil(total_train / float(BATCH_SIZE))), 
    epochs = EPOCHS, 
    validation_data = val_data_gen, 
    validation_steps = int(np.ceil(total_val / float(BATCH_SIZE)))
)
# Out:
# Epoch 1/100
# 20/20 [==============================] - 8s 401ms/step - loss: 0.8087 - accuracy: 0.4915 - val_loss: 0.6992 - val_accuracy: 0.4980
# Epoch 2/100
# 20/20 [==============================] - 8s 405ms/step - loss: 0.6919 - accuracy: 0.5235 - val_loss: 0.6915 - val_accuracy: 0.5200
# Epoch 3/100
# 20/20 [==============================] - 8s 400ms/step - loss: 0.6908 - accuracy: 0.5105 - val_loss: 0.6969 - val_accuracy: 0.5040
# Epoch 4/100
# 20/20 [==============================] - 8s 403ms/step - loss: 0.6888 - accuracy: 0.5385 - val_loss: 0.6903 - val_accuracy: 0.5320
# Epoch 5/100
# 20/20 [==============================] - 8s 405ms/step - loss: 0.6899 - accuracy: 0.5385 - val_loss: 0.6900 - val_accuracy: 0.5330
# Epoch 6/100
# 20/20 [==============================] - 8s 403ms/step - loss: 0.6863 - accuracy: 0.5425 - val_loss: 0.6969 - val_accuracy: 0.5020
# Epoch 7/100
# 20/20 [==============================] - 8s 398ms/step - loss: 0.6839 - accuracy: 0.5570 - val_loss: 0.6844 - val_accuracy: 0.5500
# Epoch 8/100
# 20/20 [==============================] - 8s 399ms/step - loss: 0.
100
# 20/20 [==============================] - 8s 397ms/step - loss: 0.3109 - accuracy: 0.8610 - val_loss: 1.1337 - val_accuracy: 0.6160
# Epoch 42/100
# 20/20 [==============================] - 8s 396ms/step - loss: 0.2650 - accuracy: 0.8865 - val_loss: 1.2721 - val_accuracy: 0.6170
# Epoch 43/100
# 20/20 [==============================] - 8s 394ms/step - loss: 0.2740 - accuracy: 0.8670 - val_loss: 1.0116 - val_accuracy: 0.6090
# Epoch 44/100
# 20/20 [==============================] - 8s 395ms/step - loss: 0.2587 - accuracy: 0.8845 - val_loss: 1.2865 - val_accuracy: 0.6240
# Epoch 45/100
# 20/20 [==============================] - 8s 399ms/step - loss: 0.2399 - accuracy: 0.8945 - val_loss: 1.2563 - val_accuracy: 0.6180
# Epoch 46/100
# 20/20 [==============================] - 8s 398ms/step - loss: 0.2278 - accuracy: 0.8890 - val_loss: 1.4214 - val_accuracy: 0.6330
# Epoch 47/100
# 20/20 [==============================] - 8s 396ms/step - loss: 0.1776 - accuracy: 0.9260 - val_loss: 1.6371 - val_accuracy: 0.6040
# Epoch 48/100
# 20/20 [==============================] - 8s 394ms/step - loss: 0.1302 - accuracy: 0.9440 - val_loss: 1.4749 - val_accuracy: 0.6480
# Epoch 49/100
# 20/20 [==============================] - 8s 399ms/step - loss: 0.1208 - accuracy: 0.9520 - val_loss: 1.9286 - val_accuracy: 0.6330
# Epoch 50/100
# 20/20 [==============================] - 8s 399ms/step - loss: 0.0745 - accuracy: 0.9730 - val_loss: 2.0475 - val_accuracy: 0.6420
# Epoch 51/100
# 20/20 [==============================] - 8s 393ms/step - loss: 0.0518 - accuracy: 0.9800 - val_loss: 2.3304 - val_accuracy: 0.6250
# Epoch 52/100
# 20/20 [==============================] - 8s 394ms/step - loss: 0.0357 - accuracy: 0.9870 - val_loss: 2.5004 - val_accuracy: 0.6230
# Epoch 53/100
# 20/20 [==============================] - 8s 395ms/step - loss: 0.0210 - accuracy: 0.9950 - val_loss: 2.7694 - val_accuracy: 0.6200
# Epoch 54/100
# 20/20 [==============================] - 8s 397ms/step - loss: 0.0117 - accuracy: 0.9985 - val_loss: 3.1860 - val_accuracy: 0.6210
# Epoch 55/100
# 20/20 [==============================] - 8s 396ms/step - loss: 0.0079 - accuracy: 0.9995 - val_loss: 3.2510 - val_accuracy: 0.6290
# Epoch 56/100
# 20/20 [==============================] - 8s 397ms/step - loss: 0.0092 - accuracy: 0.9985 - val_loss: 3.6041 - val_accuracy: 0.6290
# Epoch 57/100
# 20/20 [==============================] - 8s 395ms/step - loss: 0.0120 - accuracy: 0.9970 - val_loss: 3.7169 - val_accuracy: 0.6480
# Epoch 58/100
# 20/20 [==============================] - 8s 394ms/step - loss: 0.0227 - accuracy: 0.9945 - val_loss: 3.4743 - val_accuracy: 0.6200
# Epoch 59/100
# 20/20 [==============================] - 8s 394ms/step - loss: 0.0340 - accuracy: 0.9900 - val_loss: 3.1164 - val_accuracy: 0.6420
# Epoch 60/100
# 20/20 [==============================] - 8s 394ms/step - loss: 0.1024 - accuracy: 0.9660 - val_loss: 3.3183 - val_accuracy: 0.6100
# Epoch 61/100
# 20/20 [==============================] - 8s 396ms/step - loss: 0.1039 - accuracy: 0.9640 - val_loss: 2.6399 - val_accuracy: 0.6180
# Epoch 62/100
# 20/20 [==============================] - 8s 394ms/step - loss: 0.0756 - accuracy: 0.9735 - val_loss: 2.4959 - val_accuracy: 0.6240
# Epoch 63/100
# 20/20 [==============================] - 8s 395ms/step - loss: 0.0402 - accuracy: 0.9885 - val_loss: 2.6813 - val_accuracy: 0.6300
# Epoch 64/100
# 20/20 [==============================] - 8s 396ms/step - loss: 0.0090 - accuracy: 0.9980 - val_loss: 3.4372 - val_accuracy: 0.6180
# Epoch 65/100
# 20/20 [==============================] - 8s 405ms/step - loss: 0.0031 - accuracy: 1.0000 - val_loss: 3.6684 - val_accuracy: 0.6140
# Epoch 66/100
# 20/20 [==============================] - 8s 403ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 3.3140 - val_accuracy: 0.6230
# Epoch 67/100
# 20/20 [==============================] - 8s 392ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 3.6269 - val_accuracy: 0.6200
# Epoch 68/100
# 20/20 [==============================] - 8s 394ms/step - loss: 9.2341e-04 - accuracy: 1.0000 - val_loss: 3.5246 - val_accuracy: 0.6430
# Epoch 69/100
# 20/20 [==============================] - 8s 398ms/step - loss: 7.4060e-04 - accuracy: 1.0000 - val_loss: 3.5960 - val_accuracy: 0.6310
# Epoch 70/100
# 20/20 [==============================] - 8s 396ms/step - loss: 6.3408e-04 - accuracy: 1.0000 - val_loss: 3.7445 - val_accuracy: 0.6310
# Epoch 71/100
# 20/20 [==============================] - 8s 397ms/step - loss: 5.6614e-04 - accuracy: 1.0000 - val_loss: 3.8189 - val_accuracy: 0.6290
# Epoch 72/100
# 20/20 [==============================] - 8s 396ms/step - loss: 5.0495e-04 - accuracy: 1.0000 - val_loss: 3.7799 - val_accuracy: 0.6300
# Epoch 73/100
# 20/20 [==============================] - 8s 398ms/step - loss: 4.6851e-04 - accuracy: 1.0000 - val_loss: 3.7602 - val_accuracy: 0.6380
# Epoch 74/100
# 20/20 [==============================] - 8s 401ms/step - loss: 3.8312e-04 - accuracy: 1.0000 - val_loss: 3.7843 - val_accuracy: 0.6320
# Epoch 75/100
# 20/20 [==============================] - 8s 402ms/step - loss: 3.7529e-04 - accuracy: 1.0000 - val_loss: 4.3095 - val_accuracy: 0.6330
# Epoch 76/100
# 20/20 [==============================] - 8s 398ms/step - loss: 3.4285e-04 - accuracy: 1.0000 - val_loss: 3.7860 - val_accuracy: 0.6380
# Epoch 77/100
# 20/20 [==============================] - 8s 397ms/step - loss: 3.2898e-04 - accuracy: 1.0000 - val_loss: 3.7235 - val_accuracy: 0.6450
# Epoch 78/100
# 20/20 [==============================] - 8s 395ms/step - loss: 2.8392e-04 - accuracy: 1.0000 - val_loss: 4.1566 - val_accuracy: 0.6280
# Epoch 79/100
# 20/20 [==============================] - 8s 402ms/step - loss: 2.7481e-04 - accuracy: 1.0000 - val_loss: 4.2549 - val_accuracy: 0.6250
# Epoch 80/100
# 20/20 [==============================] - 8s 395ms/step - loss: 2.5879e-04 - accuracy: 1.0000 - val_loss: 3.7484 - val_accuracy: 0.6450
# Epoch 81/100
# 20/20 [==============================] - 8s 399ms/step - loss: 2.2888e-04 - accuracy: 1.0000 - val_loss: 4.1484 - val_accuracy: 0.6370
# Epoch 82/100
# 20/20 [==============================] - 8s 396ms/step - loss: 2.3280e-04 - accuracy: 1.0000 - val_loss: 4.1084 - val_accuracy: 0.6430
# Epoch 83/100
# 20/20 [==============================] - 8s 398ms/step - loss: 2.0199e-04 - accuracy: 1.0000 - val_loss: 4.0270 - val_accuracy: 0.6450
# Epoch 84/100
# 20/20 [==============================] - 8s 401ms/step - loss: 1.9890e-04 - accuracy: 1.0000 - val_loss: 4.3928 - val_accuracy: 0.6060
# Epoch 85/100
# 20/20 [==============================] - 8s 402ms/step - loss: 1.8290e-04 - accuracy: 1.0000 - val_loss: 4.2473 - val_accuracy: 0.6510
# Epoch 86/100
# 20/20 [==============================] - 8s 401ms/step - loss: 1.8273e-04 - accuracy: 1.0000 - val_loss: 4.1096 - val_accuracy: 0.6380
# Epoch 87/100
# 20/20 [==============================] - 8s 411ms/step - loss: 1.6370e-04 - accuracy: 1.0000 - val_loss: 4.0959 - val_accuracy: 0.6350
# Epoch 88/100
# 20/20 [==============================] - 8s 410ms/step - loss: 1.5665e-04 - accuracy: 1.0000 - val_loss: 4.4610 - val_accuracy: 0.6280
# Epoch 89/100
# 20/20 [==============================] - 8s 402ms/step - loss: 1.5072e-04 - accuracy: 1.0000 - val_loss: 4.2235 - val_accuracy: 0.6350
# Epoch 90/100
# 20/20 [==============================] - 8s 405ms/step - loss: 1.4710e-04 - accuracy: 1.0000 - val_loss: 4.1703 - val_accuracy: 0.6460
# Epoch 91/100
# 20/20 [==============================] - 8s 405ms/step - loss: 1.3240e-04 - accuracy: 1.0000 - val_loss: 4.3547 - val_accuracy: 0.6340
# Epoch 92/100
# 20/20 [==============================] - 8s 410ms/step - loss: 1.3356e-04 - accuracy: 1.0000 - val_loss: 4.1755 - val_accuracy: 0.6450
# Epoch 93/100
# 20/20 [==============================] - 8s 403ms/step - loss: 1.2368e-04 - accuracy: 1.0000 - val_loss: 4.5700 - val_accuracy: 0.6160
# Epoch 94/100
# 20/20 [==============================] - 8s 407ms/step - loss: 1.1909e-04 - accuracy: 1.0000 - val_loss: 4.3885 - val_accuracy: 0.6420
# Epoch 95/100
# 20/20 [==============================] - 8s 403ms/step - loss: 1.1124e-04 - accuracy: 1.0000 - val_loss: 4.3869 - val_accuracy: 0.6270
# Epoch 96/100
# 20/20 [==============================] - 8s 407ms/step - loss: 1.1076e-04 - accuracy: 1.0000 - val_loss: 4.5079 - val_accuracy: 0.6330
# Epoch 97/100
# 20/20 [==============================] - 8s 398ms/step - loss: 1.0210e-04 - accuracy: 1.0000 - val_loss: 4.3434 - val_accuracy: 0.6400
# Epoch 98/100
# 20/20 [==============================] - 8s 411ms/step - loss: 9.9695e-05 - accuracy: 1.0000 - val_loss: 4.7151 - val_accuracy: 0.6280
# Epoch 99/100
# 20/20 [==============================] - 8s 398ms/step - loss: 9.7014e-05 - accuracy: 1.0000 - val_loss: 4.1393 - val_accuracy: 0.6440
# Epoch 100/100
# 20/20 [==============================] - 8s 399ms/step - loss: 9.3731e-05 - accuracy: 1.0000 - val_loss: 4.4804 - val_accuracy: 0.6330

# %%
#@title Visualizing Results Of The Training

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(EPOCHS)

plt.figure(figsize = (8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label = 'Training Accuracy')
plt.plot(epochs_range, val_acc, label = 'Validation Accuracy')
plt.legend(loc = 'lower right')
plt.title('Training And Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label = 'Training Loss')
plt.plot(epochs_range, val_loss, label = 'Validation Loss')
plt.legend(loc = 'upper right')
plt.title('Taining And Validation Loss')
plt.savefig('./foo.png')
plt.show()
